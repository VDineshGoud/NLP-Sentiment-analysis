# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! unzip '/content/drive/MyDrive/nlp project/txt_reviews.zip' -d '/content/TT3'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/TT3/txt_reviews/review_95499.txt
#   inflating: /content/TT3/txt_reviews/review_955.txt
#   inflating: /content/TT3/txt_reviews/review_9550.txt
#   inflating: /content/TT3/txt_reviews/review_95500.txt
#   inflating: /content/TT3/txt_reviews/review_95501.txt
#   inflating: /content/TT3/txt_reviews/review_95502.txt
#   inflating: /content/TT3/txt_reviews/review_95503.txt
#   inflating: /content/TT3/txt_reviews/review_95504.txt
#   inflating: /content/TT3/txt_reviews/review_95505.txt
#   inflating: /content/TT3/txt_reviews/review_95506.txt
#   inflating: /content/TT3/txt_reviews/review_95507.txt
#   inflating: /content/TT3/txt_reviews/review_95508.txt
#   inflating: /content/TT3/txt_reviews/review_95509.txt
#   inflating: /content/TT3/txt_reviews/review_9551.txt
#   inflating: /content/TT3/txt_reviews/review_95510.txt
#   inflating: /content/TT3/txt_reviews/review_95511.txt
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'drive', 'sample_data']

# %%
root_dir=("/content/TT2/txt_reviews")

# %%
file_names = os.listdir("/content/TT3/txt_reviews")

# %%
len(file_names)

# %%
import pandas as pd

# %%
product_id=[]
userid=[]
profilename=[]
helpnessnumerator=[]
helpnessdenominator=[]
score=[]
time=[]
reviewsummary=[]
reviewtext=[]
for i in file_names:
    with open("/content/TT3/txt_reviews/"+i,"r") as f:
        d=f.readlines()
        p=d[0].split(":")
        u=d[1].split(":")
        pr=d[2].split(":")
        he=d[3].split(":")
        hel=d[4].split(":")
        s=d[5].split(":")
        t=d[6].split(":")
        rs=d[7].split(":")
        rt=d[8].split(":")
        product_id.append(p[1])
        userid.append(u[1])
        profilename.append(pr[1])
        helpnessnumerator.append(he[1])
        helpnessdenominator.append(hel[1])
        score.append(s[1])
        time.append(t[1])
        reviewsummary.append(rs[1])
        reviewtext.append(rt[1])
df=pd.DataFrame({"productid":product_id,"userid":userid,"profilename":profilename,"helpnessnumerator":helpnessnumerator
                 ,"helpnessdenominator":helpnessdenominator,"score":score,"time":time,"reviewsummary":reviewsummary,
                 "reviewtext":reviewtext})
df.head()
# Out:
#        productid             userid                 profilename  \
# 0   B000UU8KA2\n   A3PTDVALS7JJGA\n                   vicop69\n
# 1   B0002DGRRA\n   A38AN6ZRMHV6EU\n         Carole S. Stabile\n
# 2   B008JHZ150\n   A1F7YU6O5RU432\n            Angela Streiff\n
# 3   B000EH4XZM\n    AQ1G6JEBH5QWY\n     Ms. Diane C. Frandsen\n
# 4   B00024D9X4\n   A1P85GZIZSL9IE\n   Julia Osborn "texasmom"\n
#
#   helpnessnumerator helpnessdenominator score           time  \
# 0               0\n                 0\n   5\n   1318896000\n
# 1               0\n                 0\n   5\n   1243382400\n
# 2               1\n                 1\n   5\n   1347580800\n
# 3               0\n                 0\n   4\n   1224806400\n
# 4               1\n                 1\n   1\n   1301097600\n
#
#                                reviewsummary  \
# 0                             Rain-Blo Gum\n
# 1                                Happy Dog\n
# 2   A delicious hot sauce with some flavor\n
# ...

# %%
df.describe()
# Out:
#             productid             userid          profilename  \
# count          568454             568454               568454
# unique          74258             256059               218407
# top      B007JFMH8M\n   A3OXHLG6DIBRW8\n   C. F. Hill "CFH"\n
# freq              913                448                  451
#
#        helpnessnumerator helpnessdenominator   score           time  \
# count             568454              568454  568454         568454
# unique               231                 234       5           3168
# top                  0\n                 0\n     5\n   1350345600\n
# freq              303826              270052  363122           1143
#
#         reviewsummary      reviewtext
# count          568454          568454
# unique         295465          391202
# top      Delicious!\n   <a href="http
# freq             2462            1446

# %% [markdown]
# # The Total length  of the Dataset

# %%
print('Total number of files in the dataset:', len(df))
# Out:
# Total number of files in the dataset: 568454

# %% [markdown]
# Removed the "\n" using strip

# %%
for i in df.columns:
    df[i]=df[i].apply(lambda x: x.strip("\n"))

# %%
df
# Out:
#           productid           userid               profilename  \
# 0        B000UU8KA2   A3PTDVALS7JJGA                   vicop69
# 1        B0002DGRRA   A38AN6ZRMHV6EU         Carole S. Stabile
# 2        B008JHZ150   A1F7YU6O5RU432            Angela Streiff
# 3        B000EH4XZM    AQ1G6JEBH5QWY     Ms. Diane C. Frandsen
# 4        B00024D9X4   A1P85GZIZSL9IE   Julia Osborn "texasmom"
# ...             ...              ...                       ...
# 568449   B002CIP8OQ   A25GSFMKH8B52D              steven malia
# 568450   B0026RQTGE   A2WUK1O9802GNW               Ichiro "IT"
# 568451   B000F9XBDE   A13C90XAUL1K81    Elle M. "Literary Mom"
# 568452   B0032CJPOK   A3OQ40N5PAFIBQ               Mrs. Deming
# 568453   B0046HLZ9S    AR7Q245YM2EES                 sternhift
#
#        helpnessnumerator helpnessdenominator score       time  \
# 0                      0                   0     5 2011-10-18
# 1                      0                   0     5 2009-05-27
# ...

# %% [markdown]
# # Saved the file into csv in drive

# %%
df.to_csv("/content/drive/MyDrive/nlp project/nsave.csv")

# %%
df=pd.read_csv("/content/drive/MyDrive/nlp project/nsave.csv")

# %%
df
# Out:
#         Unnamed: 0    productid           userid               profilename  \
# 0                0   B000UU8KA2   A3PTDVALS7JJGA                   vicop69
# 1                1   B0002DGRRA   A38AN6ZRMHV6EU         Carole S. Stabile
# 2                2   B008JHZ150   A1F7YU6O5RU432            Angela Streiff
# 3                3   B000EH4XZM    AQ1G6JEBH5QWY     Ms. Diane C. Frandsen
# 4                4   B00024D9X4   A1P85GZIZSL9IE   Julia Osborn "texasmom"
# ...            ...          ...              ...                       ...
# 568449      568449   B002CIP8OQ   A25GSFMKH8B52D              steven malia
# 568450      568450   B0026RQTGE   A2WUK1O9802GNW               Ichiro "IT"
# 568451      568451   B000F9XBDE   A13C90XAUL1K81    Elle M. "Literary Mom"
# 568452      568452   B0032CJPOK   A3OQ40N5PAFIBQ               Mrs. Deming
# 568453      568453   B0046HLZ9S    AR7Q245YM2EES                 sternhift
#
#         helpnessnumerator  helpnessdenominator  score        time  \
# ...

# %% [markdown]
# # coverting the datatypes using astype to respective Dtypes

# %%
df['time']=df['time'].astype('int')

# %%
df['helpnessnumerator']=df['helpnessnumerator'].astype(int)
df['helpnessdenominator']=df['helpnessdenominator'].astype(int)
df['score']=df['score'].astype(int)

# %%
import re
from datetime import datetime

# %%
df["time"]=df["time"].apply(lambda x:''.join(re.findall('(.*)T',datetime.fromtimestamp(x).isoformat())))

# %%
df.time=pd.to_datetime(df.time)

# %%
df
# Out:
#         Unnamed: 0    productid           userid               profilename  \
# 0                0   B000UU8KA2   A3PTDVALS7JJGA                   vicop69
# 1                1   B0002DGRRA   A38AN6ZRMHV6EU         Carole S. Stabile
# 2                2   B008JHZ150   A1F7YU6O5RU432            Angela Streiff
# 3                3   B000EH4XZM    AQ1G6JEBH5QWY     Ms. Diane C. Frandsen
# 4                4   B00024D9X4   A1P85GZIZSL9IE   Julia Osborn "texasmom"
# ...            ...          ...              ...                       ...
# 568449      568449   B002CIP8OQ   A25GSFMKH8B52D              steven malia
# 568450      568450   B0026RQTGE   A2WUK1O9802GNW               Ichiro "IT"
# 568451      568451   B000F9XBDE   A13C90XAUL1K81    Elle M. "Literary Mom"
# 568452      568452   B0032CJPOK   A3OQ40N5PAFIBQ               Mrs. Deming
# 568453      568453   B0046HLZ9S    AR7Q245YM2EES                 sternhift
#
#         helpnessnumerator  helpnessdenominator  score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           568454 non-null  int64
#  1   productid            568454 non-null  object
#  2   userid               568454 non-null  object
#  3   profilename          568454 non-null  object
#  4   helpnessnumerator    568454 non-null  int64
#  5   helpnessdenominator  568454 non-null  int64
#  6   score                568454 non-null  int64
#  7   time                 568454 non-null  datetime64[ns]
#  8   reviewsummary        568454 non-null  object
#  9   reviewtext           568454 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 43.4+ MB

# %%
df.describe()
# Out:
#           Unnamed: 0  helpnessnumerator  helpnessdenominator          score
# count  568454.000000      568454.000000         568454.00000  568454.000000
# mean   284226.500000           1.743817              2.22881       4.183199
# std    164098.679298           7.636513              8.28974       1.310436
# min         0.000000           0.000000              0.00000       1.000000
# 25%    142113.250000           0.000000              0.00000       4.000000
# 50%    284226.500000           0.000000              1.00000       5.000000
# 75%    426339.750000           2.000000              2.00000       5.000000
# max    568453.000000         866.000000            923.00000       5.000000

# %% [markdown]
# # Checking the null values:

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# productid              0
# userid                 0
# profilename            0
# helpnessnumerator      0
# helpnessdenominator    0
# score                  0
# time                   0
# reviewsummary          0
# reviewtext             0
# dtype: int64

# %% [markdown]
# # checking the duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.score.value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: score, dtype: int64

# %% [markdown]
# # splitiing the data into input and output

# %%
x=df[['reviewtext']]
y=df['score']

# %% [markdown]
# # spliting the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size= 0.2,random_state=42)

# %%
X_train.head()
# Out:
#                                                reviewtext
# 251349   Great coffee!<br />I should not have purchase...
# 523262   I'm going to ride on the previous reviewer's ...
# 224543   I am a huge fan of Community Coffee.  The com...
# 291632   Had this sent to me in Afghanistan. The flavo...
# 37385    Bodie, our 2 year old Maltese-Yorkie "foodie ...

# %%
X_train.shape
# Out:
# (454763, 1)

# %% [markdown]
# # Downloaded the nltk for data preprocessing

# %%
import nltk 
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# # Imported the nltk for Data preprocessing(Data cleaning, Data tranformation)

# %%
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords 
from nltk.stem import PorterStemmer  
from nltk.stem import WordNetLemmatizer

# %%
stemmer=PorterStemmer()

lemmatizer=WordNetLemmatizer()

# %%
def preprocess(raw_text,flag):

  # Removing special character and digits
  sentence=re.sub("[^a-zA-Z]"," ",raw_text)

  # Change into lower case
  sentence=sentence.lower()

  c=sentence.split()

  clean=[ i for i in c if i!="br"]

  # tokenize into words
  tokens=[i  for i in clean if not i in stopwords.words("english")]

  # stemming / lemmatization
  if (flag=="stem"):  
        tokens=[stemmer.stem(word)  for word in tokens]
    else:
        tokens=[lemmatizer.lemmatize(word) for word in tokens]

return pd.Series([" ".join(tokens),len(tokens)])

# %%
from tqdm import tqdm,tqdm_notebook

# %%
tqdm.pandas()

# %%
import re

# %% [markdown]
# # Preprocessing the Train data

# %%
temp_df=X_train["reviewtext"].progress_apply(lambda x : preprocess(x,"stem"))
# Out:
# 100%|██████████| 454763/454763 [1:30:38<00:00, 83.62it/s]

# %%
X_train=pd.concat([X_train,temp_df],axis=1)

# %%
temp_df.columns=(['clean_text_stem','text_len_stem'])
temp_df.head()
# Out:
#                                           clean_text_stem  text_len_stem
# 251349  great coffe purchas lb bag aw lot coffe two pe...             23
# 523262  go ride previou review comment except use bake...             36
# 224543  huge fan commun coffe compani often run specia...             79
# 291632  sent afghanistan flavor enjoy spici made quail...             15
# 37385   bodi year old maltes yorki foodi snob love tre...             48

# %%
temp_df=X_train['reviewtext'].progress_apply(lambda x : preprocess(x,'lem'))
# Out:
# 100%|██████████| 454763/454763 [1:21:18<00:00, 93.21it/s]

# %%
temp_df.columns=(['clean_text_lem','text_length_lem'])
temp_df
# Out:
#                                            clean_text_lem  text_length_lem
# 251349  great coffee purchased lb bag awful lot coffee...               23
# 523262  going ride previous reviewer comment exception...               36
# 224543  huge fan community coffee company often run sp...               79
# 291632  sent afghanistan flavor enjoyable spicy made q...               15
# 37385   bodie year old maltese yorkie foodie snob love...               48
# ...                                                   ...              ...
# 110268                      usually hit wall right around                5
# 259178  buy every year xmas party also gift always hap...               12
# 365838  brownie strange wet texture completely cooked ...               24
# 131932  gave try great price unfortunately case get pa...               15
# 121958  maxwell house lite coffee quite similar folger...               35
#
# [454763 rows x 2 columns]

# %%
X_train=pd.concat([X_train,temp_df],axis=1)

# %%
X_train.head()
# Out:
#                                                reviewtext  \
# 251349   Great coffee!<br />I should not have purchase...
# 523262   I'm going to ride on the previous reviewer's ...
# 224543   I am a huge fan of Community Coffee.  The com...
# 291632   Had this sent to me in Afghanistan. The flavo...
# 37385    Bodie, our 2 year old Maltese-Yorkie "foodie ...
#
#                                                         0   1  \
# 251349  great coffe purchas lb bag aw lot coffe two pe...  23
# 523262  go ride previou review comment except use bake...  36
# 224543  huge fan commun coffe compani often run specia...  79
# 291632  sent afghanistan flavor enjoy spici made quail...  15
# 37385   bodi year old maltes yorki foodi snob love tre...  48
#
#                                            clean_text_lem  text_length_lem
# 251349  great coffee purchased lb bag awful lot coffee...               23
# 523262  going ride previous reviewer comment exception...               36
# ...

# %% [markdown]
# # Converting Text to Numerical vectors - BOW Representation

# %%
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()

X_train_bow = vocab.fit_transform(X_train['clean_text_lem'])

# %%
X_train_bow
# Out:
# <454763x83227 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13462410 stored elements in Compressed Sparse Row format>

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words: 83227
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (454763, 83227)

# %% [markdown]
# # Preprocessing the Test Data

# %%
X_test.head()
# Out:
#                                                reviewtext
# 165256   I like the product itself but price here is t...
# 231465   Paid over $4.00 for a cup of this at a coffee...
# 427827   *****<br />This milk chocolate from Dagoba is...
# 433954   One of my three could be the poster cat for t...
# 70260    Wonderful ancho flavor. So much better than t...

# %%
temp_df=X_test['reviewtext'].progress_apply(lambda x : preprocess(x,'lem'))
# Out:
# 100%|██████████| 113691/113691 [21:24<00:00, 88.51it/s]

# %%
temp_df.columns=['clean_text_lem',	'text_length_lem']

# %%
X_test=pd.concat([temp_df,X_test],axis=1)
X_test.head()
# Out:
#                                            clean_text_lem  text_length_lem  \
# 165256  like product price high apr buy set tomato pas...               14
# 231465  paid cup coffee shop town raving delicious thi...               61
# 427827  milk chocolate dagoba organic unbelievably scr...               61
# 433954  one three could poster cat always asking love ...               26
# 70260   wonderful ancho flavor much better typical sup...               36
#
#                                                reviewtext
# 165256   I like the product itself but price here is t...
# 231465   Paid over $4.00 for a cup of this at a coffee...
# 427827   *****<br />This milk chocolate from Dagoba is...
# 433954   One of my three could be the poster cat for t...
# 70260    Wonderful ancho flavor. So much better than t...

# %% [markdown]
# # Converting the Text Data to BOW

# %%
X_test_bow = vocab.transform(X_test['clean_text_lem'])

# %% [markdown]
# # Applying Algorithms on Target variable

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_bow, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(max_iter=454763)
classifier.fit(X_train_bow,y_train)
# Out:
# LogisticRegression(max_iter=454763)

# %%
y_test_pred=classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_pred))
# Out:
# 0.7542109753630455

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train_bow,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred=classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_pred))
# Out:
# 0.751299575164261

# %% [markdown]
# # RandomforestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train_bow,y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred=classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_pred))
# Out:
# 0.796826485825615

# %% [markdown]
# # Conclussion:By observing above Accuracy_score values Random forest regression has high Accuracy score compare to logisticregression ,decision tree classifier.
